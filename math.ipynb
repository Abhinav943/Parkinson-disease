# %%
import math
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

plt.style.use('default')  

def f(x):
    y = 10.10 * x + (-17.73)
    
    coeffs = [
        (4.13, -11.47),
        (5.19, -2.03),
        (0.62, 3.59),
        (0.82, -2.78),
        (-1.80, -1.27),
        (2.17, 1.10),
        (-3.00, 0.01),
        (-2.02, -0.18),
        (1.87, 1.80),
        (-2.43, -0.60)
    ]
    
    for n, (a_n, b_n) in enumerate(coeffs, start=1):
        y += a_n * np.cos(n * 0.242 * x) + b_n * np.sin(n * 0.242 * x)
    
    return y

x = np.arange(1, 27)
y = np.array([1,3,7,14,20,26,27,44,71,75,87,110,117,124,131,133,164,178,179,198,200,214,220,244,247,251])
y_1 = f(x)

print(y[20])

plt.plot(x,y,marker = '.')
plt.plot(x,y_1,marker = '.')
plt.show()
# Out:
# 200

# %%
import numpy as np
def f(x):
    y = 10.10 * x + (-17.73)
    
    coeffs = [
        (4.13, -11.47),
        (5.19, -2.03),
        (0.62, 3.59),
        (0.82, -2.78),
        (-1.80, -1.27),
        (2.17, 1.10),
        (-3.00, 0.01),
        (-2.02, -0.18),
        (1.87, 1.80),
        (-2.43, -0.60)
    ]
    
    for n, (a_n, b_n) in enumerate(coeffs, start=1):
        y += a_n * np.cos(n * 0.242 * x) + b_n * np.sin(n * 0.242 * x)
    
    return y

x = np.arange(1, 27)
y = np.array([1,3,7,14,20,26,27,44,71,75,87,110,117,124,131,133,164,178,179,198,200,214,220,244,247,251])
y_1 = f(x)
max_error = 0

for i in range(len(y)):
    max_error = max(max_error,y[i] - y_1[i])

print(max_error)
print(f(np.array([1])))
# Out:
# 3.7734381314582492
# [0.59897805]
